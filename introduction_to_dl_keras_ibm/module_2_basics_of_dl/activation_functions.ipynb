# %% [markdown]
# # Activation Functions and Vanishing Gradients
#
# ## Objective for this notebook
# * Define sigmoid activation function and its derivative
# * Define ReLu activation function and its derivative
# * Calculate the Sigmoid and ReLU activations and their derivatives for a range of input values
# * Plot the output values

# %% [markdown]
# From the videos, we have learnt that different activation functions have different type of characteristic output curves. And, the corresponding gradient values or their derivatives are also different. In certain cases, with higher input values, the derivative starts to reach to zero, vausing vanishing gradient problem. In this lab, we compare "Sigmoid" and "ReLU" activation functions and explore their derivatives for vanishing gradients.
#
# __Sigmoid Activation Function__
# * The sigmoid function transforms input values into a range between 0 and 1
# * Produces an "S-shaped" curve, making it suitable for probabilistic outputs or binary classification tasks.
# * Continuous, differentiable, and monotonically increasing across its domain (-∞, +∞).
# * Its derivative is simple to compute: σ′(z)=σ(z)⋅(1−σ(z)). This is essential for backpropagation.
# * Useful for output layers where probabilities are required (e.g., logistic regression).
# * Enables non-linear decision boundaries, allowing neural networks to learn complex relationships.
#
#   __Limitations__
#     * Suffers from the vanishing gradient problem: For large positive or negative inputs, the gradient approaches zero, slowing down learning in deep networks.
#     * Computationally expensive due to the exponential operation involved.
#
#
# __ReLU (Rectified Linear Unit) Activation Function__
#
# * ReLU outputs the maximum of zero and the input value using f(x)=max⁡(0,x)f(x)=max(0,x).
# * Non-linear but simpler than sigmoid; it outputs zero for negative inputs and the input value for positive inputs.
# * The derivative is straightforward: f′(x)=1f′(x)=1 for x>0x>0, and f′(x)=0f′(x)=0 for x≤0x≤0.
# * Mitigates the vanishing gradient problem by maintaining a constant gradient (1) for positive inputs, enabling faster convergence in deep networks.
# * Computationally efficient due to its simplicity.
#
#   __Limitations__
#
#     * Can lead to "dead neurons," where neurons output zero consistently due to negative inputs. This can be mitigated using variants like Leaky ReLU.

# %% [markdown]
# ## Install Required Libraries

# %%
# !pip install numpy==2.0.2
# !pip install matplotlib==3.9.2
# Out:
# Collecting numpy==2.0.2
#   Downloading numpy-2.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 303.2 kB/s eta 0:00:00a 0:00:01
# Downloading numpy-2.0.2-cp311-cp311-macosx_10_9_x86_64.whl (21.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 18.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.
# scikit-learn 1.4.1.post1 requires numpy<2.0,>=1.19.5, but you have numpy 2.0.2 which is incompatible.
# pyarrow 15.0.0 requires numpy<2,>=1.16.6, but you have numpy 2.0.2 which is incompatible.
# langchain-community 0.0.28 requires numpy<2,>=1, but you have numpy 2.0.2 which is incompatible.
# langchain 0.1.12 requires numpy<2,>=1, but you have numpy 2.0.2 which is incompatible.
# scipy 1.12.0 requires numpy<1.29.0,>=1.22.4, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# Requirement already satisfied: matplotlib==3.9.2 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from matplotlib==3.9.2) (2.8.2)
# Collecting numpy>=1.23 (from matplotlib==3.9.2)
#   Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: six>=1.5 in /Users/laurasalcido/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.16.0)
# Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.26.4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define Sigmoid Function 
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
# Define Sigmoid derivatives
def sigmoid_derivative(z):
    return sigmoid(z) * (1 - sigmoid(z))

# %%
# Define ReLU Function
def relu(z):
    return np.maximum(0, z)

# %%
# Define ReLU Derivative (gradient)
# returns value 1 for all z greater than 0
def relu_derivative(z):
    return np.where(z > 0, 1, 0)

# %%
# Define number of input values
z = np.linspace(-10, 10, 400)  # 400 synthetic values between -10 and 10

# %%
# compute derivatives for sigmoid and relu activations
sigmoid_grad = sigmoid_derivative(z)
relu_grad = relu_derivative(z)

# %% [markdown]
# ## Visualize activations and gradients

# %%
# Plot the activation functions
plt.figure(figsize=(12, 6))

# Plot Sigmoid and its derivative
plt.subplot(1, 2, 1)
plt.plot(z, sigmoid(z), label='Sigmoid Activation', color='b')
plt.plot(z, sigmoid_grad, label="Sigmoid Derivative", color='r', linestyle='--')
plt.title('Sigmoid Activation & Gradient')
plt.xlabel('Input Value (z)')
plt.ylabel('Activation / Gradient')
plt.legend()

# Plot ReLU and its derivative
plt.subplot(1, 2, 2)
plt.plot(z, relu(z), label='ReLU Activation', color='g')
plt.plot(z, relu_grad, label="ReLU Derivative", color='r', linestyle='--')
plt.title('ReLU Activation & Gradient')
plt.xlabel('Input Value (z)')
plt.ylabel('Activation / Gradient')
plt.legend()

plt.tight_layout()
plt.show()

# %%
## Tanh
def tanh(z):
    return np.tanh(z)

def tanh_derivative(z):
    return 1 - np.tanh(z) ** 2

# %%
tanh_grad = tanh_derivative(z)

# %%
# Plot the activation functions
plt.figure(figsize=(12, 6))

# Plot tanh and its derivative
plt.subplot(1, 2, 1)
plt.plot(z, tanh(z), label='tanh Activation', color='b')
plt.plot(z, tanh_grad, label="tanh Derivative", color='r', linestyle='--')
plt.title('tanh Activation & Gradient')
plt.xlabel('Input Value (z)')
plt.ylabel('Activation / Gradient')
plt.legend()

plt.tight_layout()
plt.show()
